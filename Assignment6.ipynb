# %% [markdown]
# # Question 1
#
# Object-oriented programming is a methodology of programming in which the idea of objects to represent data and methods, is used.
# Their are four pillars of object-oriented programming: encapsulation, abstraction, inheritance, and polymorphism.
#
# ### Encapsulation
# It describes the idea of bundling data and methods that work on that data within one unit e.g. a class. This concept is also often used to hide the internal representation, or state, of an object from the outside.
#
# ### Abstraction
# Abstraction is selecting data from a larger pool to show only the relevant details to the object. It helps to reduce programming complexity and effort.
#
# ### Inheritance
# Inheritance is a mechanism in which one class acquires the property of another class.
#
# ### Polymorphism
# Polymorphism is the ability of an object to take on many forms.

# %% [markdown]
# # Question 2
#
# ### Benefits of OOP
#
#  - Better Productivity as OOP techniques enforce rules on a programmer that, in the long run, help her get more work done; finished programs work better, have more features and are easier to read and maintain.
#  - Objects can also be reused within an across applications. The reuse of software also lowers the cost of development.
#  - It provides a clear modular structure for programs which makes it good for defining abstract datatypes in which implementation details are hidden.

# %% [markdown]
# # Question 3
#
# A function is a piece of code that is called by name. It can be passed data to operate on (i.e. the parameters) and can optionally return data (the return value). All data that is passed to a function is explicitly passed.
#
# A method is a piece of code that is called by a name that is associated with an object. In most respects it is identical to a function except for two key differences:
#
# 1. A method is implicitly passed the object on which it was called.
# 2. A method is able to operate on data that is contained within the class.

# %% [markdown]
# # Question 4
#
# 1. #### Class
# A class is a blueprint for creating objects (a particular data structure), providing initial values for state (member variables or attributes), and implementations of behavior (member functions or methods).
#
# 2. #### Object
# Object-oriented programming is a programming paradigm based on the concept of "objects", which can contain data, in the form of fields, and code, in the form of procedures. A feature of objects is an object's procedures that can access and often modify the data fields of the object with which they are associated.
#
# 3. #### Attribute
# In Object-oriented programming(OOP), classes and objects have attributes. Attributes are data stored inside a class or instance and represent the state or quality of the class or instance. In short, attributes store information about the instance.
#
# 4. #### Behavior
# The behavior of an object is defined by its methods, which are the functions and subroutines defined within the object class. Without class methods, a class would simply be a structure. Methods determine what type of functionality a class has, how it modifies its data, and its overall behavior.

# %%
# Question 5

// Create Class

class Car:
    def __init__(self, model, color, name, car_type, price):
        self.__year_model = model
        self.__color = color
        self.__name = name
        self.__car_type = car_type
        self.__price = price
        
    def set_year_model(self, model):
        self.__year_model = model

    def set_color(self, color):
        self.__color = color
        
    def set_name(self, model):
        self.__name = name
        
    def set_car_type(self, car_type):
        self.__car_type = car_type
        
    def set_price(self, price):
        self.__price = price


    def get_year_model(self):
        return self.__year_model
    
    def get_color(self):
        return self.__color
        
    def get_name(self):
        return self.__name
        
    def get_car_type(self):
        return self.__car_type
        
    def get_price(self):
        return self.__price
  
    
    def used_car(self):
        self.__price /= 1.25

    def install_cng(self):
        self.__price *= 1.15

    def get_car_price(self):
        return self.__price

    
// create instances of the class

    mehran_model = 2010
    mehran_color = 'white'
    mehran_name = 'Suzuki Mehran'
    mehran_car_type = 'small'
    mehran_price = 500000

    suzuki_mehran = Car(mehran_model, mehran_color, mehran_name, mehran_car_type, mehran_price)
    
    alto_model = 2019
    alto_color = 'silver'
    alto_name = 'Suzuki Alto'
    alto_car_type = 'small'
    alto_price = 1200000

    suzuki_alto = Car(alto_model, alto_color, alto_name, alto_car_type, alto_price)

    civic_model = 2019
    civic_color = 'black'
    civic_name = 'Honda Civic'
    civic_car_type = 'sedan'
    civic_price = 4000000

    honda_civic = Car(civic_model, civic_color, civic_name, civic_car_type, civic_price)
    
    
    corolla_model = 2019
    corolla_color = 'black'
    corolla_name = 'Toyota Corolla'
    corolla_car_type = 'sedan'
    corolla_price = 4000000

    toyota_corolla = Car(corolla_model, corolla_color, corolla_name, corolla_car_type, corolla_price)
    
    sportage_model = 2019
    sportage_color = 'red'
    sportage_name = 'Kia Sportage'
    sportage_car_type = 'SUV'
    sportage_price = 4700000

    kia_sportage  = Car(sportage_model, sportage_color, sportage_name, sportage_car_type, sportage_price)
